# %% [markdown]
# # 股票数据读取和可视化

# %%
import tushare as ts
pro_api = ts.pro_api(token='a6387a7ea9d71482fec4318a249647a9d62214807d0664722eecd43f')
get_data = pro_api.daily(ts_code='000001.SZ', start_date='20130101', end_date='20230101')

get_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      ts_code trade_date   open   high    low  close  pre_close  change  \
# 0  000001.SZ   20221230  13.04  13.28  12.96  13.16      13.03    0.13
# 1  000001.SZ   20221229  13.07  13.13  12.85  13.03      13.14   -0.11
# 2  000001.SZ   20221228  13.16  13.38  13.00  13.14      13.11    0.03
# 3  000001.SZ   20221227  12.87  13.22  12.87  13.11      12.77    0.34
# 4  000001.SZ   20221226  12.99  13.04  12.71  12.77      12.98   -0.21
#
#    pct_chg        vol       amount
# 0   0.9977  818035.98  1074756.754
# 1  -0.8371  666890.09   865144.967
# 2   0.2288  791191.98  1042402.080
# 3   2.6625  886004.12  1160090.119
# 4  -1.6179  797119.87  1021903.963

# %%
# 保存 csv
get_data.to_csv('./股票数据.csv', index=False)

# %% [markdown]
# ## 绘制股价走势图

# %%
import pandas as pd
read_data = pd.read_csv('股票数据.csv')

read_data
# Out:
#         ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0     000001.SZ    20221230  13.04  13.28  12.96  13.16      13.03    0.13
# 1     000001.SZ    20221229  13.07  13.13  12.85  13.03      13.14   -0.11
# 2     000001.SZ    20221228  13.16  13.38  13.00  13.14      13.11    0.03
# 3     000001.SZ    20221227  12.87  13.22  12.87  13.11      12.77    0.34
# 4     000001.SZ    20221226  12.99  13.04  12.71  12.77      12.98   -0.21
# ...         ...         ...    ...    ...    ...    ...        ...     ...
# 2423  000001.SZ    20130110  15.86  16.10  15.79  15.87      15.86    0.01
# 2424  000001.SZ    20130109  15.96  16.02  15.80  15.86      16.00   -0.14
# 2425  000001.SZ    20130108  16.30  16.37  15.86  16.00      16.30   -0.30
# 2426  000001.SZ    20130107  15.98  16.35  15.88  16.30      15.99    0.31
# 2427  000001.SZ    20130104  16.32  16.45  15.92  15.99      16.02   -0.03
#
#       pct_chg        vol        amount
# ...

# %%
# read_data.set_index('trade_date', inplace=True)

read_data.head()
# Out:
#      ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0  000001.SZ    20221230  13.04  13.28  12.96  13.16      13.03    0.13
# 1  000001.SZ    20221229  13.07  13.13  12.85  13.03      13.14   -0.11
# 2  000001.SZ    20221228  13.16  13.38  13.00  13.14      13.11    0.03
# 3  000001.SZ    20221227  12.87  13.22  12.87  13.11      12.77    0.34
# 4  000001.SZ    20221226  12.99  13.04  12.71  12.77      12.98   -0.21
#
#    pct_chg        vol       amount
# 0   0.9977  818035.98  1074756.754
# 1  -0.8371  666890.09   865144.967
# 2   0.2288  791191.98  1042402.080
# 3   2.6625  886004.12  1160090.119
# 4  -1.6179  797119.87  1021903.963

# %%
import matplotlib.pyplot as plt
from datetime import datetime

plt.rcParams['font.sans-serif'] = ['SimHei']
# read_data['trade_date'] = read_data['trade_date'].apply(lambda x:datetime.strptime(str(x), '%Y%m%d'))

plt.figure(figsize=(50, 5), dpi=100)
plt.plot(read_data['trade_date'], read_data['close'])
plt.title('平安银行走势图')
plt.grid(linestyle='--', alpha=1)
plt.savefig('./平安银行走势图.png')
plt.show()
plt.close()
